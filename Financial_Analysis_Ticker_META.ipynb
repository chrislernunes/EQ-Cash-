# %% [markdown]
# ## <font color="red">Financial Analysis<font>

# %% [markdown]
# Date: 13/11/2022

# %% [markdown]
# This is an open-research conducted on Meta (Facebook), All material used during research are free of cost and open-source softwares, such as Jupyter Notebook, Pandas, Numpy, Seaborn, Matplotlib, Python in-built libraries and yahoo finance Api.

# %% [markdown]
# Meta has cut down, 13 per cent of its workers, which are nearly 11,000 employees.Meta with the headcount of correction, Meta still accquire more staff than it has last year. In the end of December 2021, the company had almost 72,000 staff, on last Wednesday, the cuts shrank its workforce from more than 85,000 to about 74,000.Nearly $89bn has been wiped from the company’s market capitalisation in late October, when Meta has posted declining revenues. Meta shares closed up more than 5 per cent on Wednesday.

# %% [markdown]
# #### Import Libraries

# %%
import yfinance
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import html5lib
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# %% [markdown]
# #### DS & Algorithms

# %%
stock_ticker = input("Enter Your Stock Ticker: ").upper()
stock = yfinance.Ticker(stock_ticker)
history_stock = stock.history(period="730d")
stock_data = pd.DataFrame(history_stock)
financials = stock.financials
df_financials = pd.DataFrame(financials)
financials_qtr= stock.quarterly_financials
df_financials_qtr = pd.DataFrame(financials_qtr)
balance_sheet= stock.balance_sheet
df_balance_sheet = pd.DataFrame(balance_sheet)
quarterly_balance_sheet = stock.quarterly_balance_sheet
df_quarterly_balance_sheet = pd.DataFrame(quarterly_balance_sheet)
cashflow = stock.cashflow
df_cashflow = pd.DataFrame(cashflow)
quarterly_cashflow = stock.quarterly_cashflow
df_quarterly_cashflow = pd.DataFrame(quarterly_cashflow)
earnings = stock.earnings
df_earnings = pd.DataFrame(earnings)
quarterly_earnings = stock.quarterly_earnings
df_quarterly_earnings = pd.DataFrame(quarterly_earnings)
sustainability = stock.sustainability
df_sustainability = pd.DataFrame(sustainability)
calendars = stock.calendar
df_calendars = pd.DataFrame(calendars)
options = stock.options
df_options = pd.DataFrame(options)
news = stock.news
df_news = pd.DataFrame(news)
institutional_holders = stock.institutional_holders
df_institutional_holders = pd.DataFrame(institutional_holders)
major_holders = stock.major_holders
df_major_holders = pd.DataFrame(major_holders)
splits = stock.splits
df_splits = pd.DataFrame(splits)
dividends = stock.dividends
df_dividends = pd.DataFrame(dividends)
actions= stock.actions
df_actions = pd.DataFrame(actions)
# Out:
# Enter Your Stock Ticker: meta

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### <font color="grey">1. Techincal Analysis<font>

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(15,10))
sns.scatterplot(data=stock_data, x="Date", y="Open", color="red")
plt.title(f"{stock_ticker} - Open Price ")
plt.ylabel("Open price")
plt.xlabel("Date")
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(15,10))
sns.lineplot(data=stock_data, x="Date", y="Open", color="blue")
plt.title(f"{stock_ticker} - Open Price ")
plt.ylabel("Open price")
plt.xlabel("Date")
plt.show()

# %%
stock_data.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  730.000000  730.000000  730.000000  730.000000  7.300000e+02
# mean   250.804096  254.538356  247.190438  250.847863  2.521698e+07
# std     68.894437   69.103637   68.596572   68.910614  1.744393e+07
# min     90.080002   90.459999   88.089996   88.910004  6.046300e+06
# 25%    197.085003  202.165001  193.154995  197.312496  1.555728e+07
# 50%    256.764999  260.584991  251.525002  255.065002  2.131895e+07
# 75%    312.007492  314.719994  307.747498  312.050003  2.948780e+07
# max    381.679993  384.329987  378.809998  382.179993  2.323166e+08
#
#        Dividends  Stock Splits
# count      730.0         730.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# max          0.0           0.0

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### <font color="Grey">2. Fundamental Analysis<font>

# %% [markdown]
# #### 2.1 Income statement - Annual

# %%
df_financials
# Out:
#                                             2021-12-31     2020-12-31  \
# Research Development                     24655000000.0  18447000000.0
# Effect Of Accounting Charges                      None           None
# Income Before Tax                        47284000000.0  33180000000.0
# Minority Interest                                 None           None
# Net Income                               39370000000.0  29146000000.0
# Selling General Administrative           23872000000.0  18155000000.0
# Gross Profit                             95280000000.0  69273000000.0
# Ebit                                     46753000000.0  32671000000.0
# Operating Income                         46753000000.0  32671000000.0
# Other Operating Expenses                          None           None
# Interest Expense                                  None           None
# Extraordinary Items                               None           None
# ...

# %% [markdown]
# #### <font color="blue">Graph 1 -  Annual Research and Development Analysis<font>

# %%
stock = yfinance.Ticker(stock_ticker)
stock = stock.financials
rnd_2018 = float(stock.iloc[0:1,3])
rnd_2019 = float(stock.iloc[0:1,2])
rnd_2020 = float(stock.iloc[0:1,1])
rnd_2021 = float(stock.iloc[0:1,0])
rnd = {f"{stock_ticker} 2018":rnd_2018,f"{stock_ticker} 2019":rnd_2019,f"{stock_ticker} 2020":rnd_2020,f"{stock_ticker} 2021":rnd_2021 }
if rnd_2021 > rnd_2020:
    message_1 = ("\nResearch and development has been increased")
    print(message_1)
elif rnd_2021 < rnd_2020:
    message_2 = ("\nResearch and development has been decreased")
    print(message_2)
plotdata = pd.DataFrame({f"{stock_ticker}":[(rnd_2018), (rnd_2019), (rnd_2020), (rnd_2021)]}, index=["2018","2019","2020", "2021"])
plotdata.plot(kind="bar")
plotdata[f"{stock_ticker}"].plot(kind="line", color=["red"], figsize=(10,8))
plt.title(f"{stock_ticker}")
plt.xlabel("Research Development")
plt.ylabel("Dollars ($)")
plt.show()
# Out:
# Research and development has been increased

# %% [markdown]
# #### Research and development validation

# %%
print(f"R&D 2018: ${rnd_2018}")
print(f"R&D 2019: ${rnd_2019}")
print(f"R&D 2020: ${rnd_2020}")
print(f"R&D 2021: ${rnd_2021}")
# Out:
# R&D 2018: $10273000000.0
# R&D 2019: $13600000000.0
# R&D 2020: $18447000000.0
# R&D 2021: $24655000000.0

# %%
print(f"Difference on Annual R&D: ${rnd_2021 - rnd_2020}")
# Out:
# Difference on Annual R&D: $6208000000.0

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### <font color="blue">Graph 2 - Annual Revenue<font>

# %%
stock = yfinance.Ticker(stock_ticker)
stock = stock.financials
revenue_1 = float(stock.iloc[15:16,3])
revenue_2 = float(stock.iloc[15:16,2])
revenue_3 = float(stock.iloc[15:16,1])
revenue_4 = float(stock.iloc[15:16,0])
rnd = {f"{stock_ticker} 2018":revenue_1,f"{stock_ticker} 2019":revenue_2,f"{stock_ticker} 2020":revenue_3,f"{stock_ticker} 2021":revenue_4 }
if revenue_4 > revenue_3:
    increase_revenue = revenue_4 - revenue_3
    message_1 = (f"\nRevenue has been increases ${increase_revenue}")
    print(message_1)
elif rvenue_4 < revenue_3:
    decrease_revenue= revenue_4 - revenue_3
    message_2 = (f"\nRevenue has been decreased ${decrease_revenue}")
    print(message_2)
plotdata = pd.DataFrame({f"{stock_ticker}":[(revenue_1), (revenue_2), (revenue_3), (revenue_4)]}, index=["2018","2019","2020", "2021"])
plotdata.plot(kind="bar")
plotdata[f"{stock_ticker}"].plot(kind="line", color=["red"], figsize=(10,8))
plt.title(f"{stock_ticker}")
plt.xlabel("Revenue Generated")
plt.ylabel("Dollars ($)")
plt.show()
# Out:
# Revenue has been increases $31964000000.0

# %% [markdown]
# #### Revenue validation

# %%
print(f"Revenue 2018: {revenue_1}")
print(f"Revenue 2019: {revenue_2}")
print(f"Revenue 2020: {revenue_3}")
print(f"Revenue 2021: {revenue_4}")
# Out:
# Revenue 2018: 55838000000.0
# Revenue 2019: 70697000000.0
# Revenue 2020: 85965000000.0
# Revenue 2021: 117929000000.0

# %%
print(f"Difference in Annual Revenue: ${revenue_4 - revenue_3}")
# Out:
# Difference in Annual Revenue: $31964000000.0

# %% [markdown]
# #### Income statement Quarterly

# %%
df_financials_qtr
# Out:
#                                            2022-09-30     2022-06-30  \
# Research Development                     8939000000.0   8690000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        5576000000.0   8186000000.0
# Minority Interest                                None           None
# Net Income                               4395000000.0   6687000000.0
# Selling General Administrative           7015000000.0   6582000000.0
# Gross Profit                            22031000000.0  23630000000.0
# Ebit                                     6077000000.0   8358000000.0
# Operating Income                         6077000000.0   8358000000.0
# Other Operating Expenses                         None           None
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.2 Balance Sheet - Annual

# %%
df_balance_sheet
# Out:
#                                                 2021-12-31    2020-12-31  \
# Intangible Assets                             6.340000e+08  6.230000e+08
# Capital Surplus                               5.581100e+10  5.001800e+10
# Total Liab                                    4.110800e+10  3.102600e+10
# Total Stockholder Equity                      1.248790e+11  1.282900e+11
# Other Current Liab                            1.269800e+10  1.001800e+10
# Total Assets                                  1.659870e+11  1.593160e+11
# Other Current Assets                          1.490000e+08  2.410000e+08
# Retained Earnings                             6.976100e+10  7.734500e+10
# Other Liab                                    6.721000e+09  6.414000e+09
# Good Will                                     1.919700e+10  1.905000e+10
# Gains Losses Not Affecting Retained Earnings -6.930000e+08  9.270000e+08
# Other Assets                                  2.751000e+09  2.758000e+09
# ...

# %% [markdown]
# #### <font color="blue">Graph 3 - Total Assets Analysis<font>

# %%
stock = yfinance.Ticker(stock_ticker)
balance_sheet= stock.balance_sheet
total_assets_1 = float(balance_sheet.iloc[5:6,3])
total_assets_2 = float(balance_sheet.iloc[5:6,2])
total_assets_3 = float(balance_sheet.iloc[5:6,1])
total_assets_4 = float(balance_sheet.iloc[5:6,0])
rnd = {f"{stock_ticker} 2018":total_assets_1,f"{stock_ticker} 2019":total_assets_2,f"{stock_ticker} 2020":total_assets_3,f"{stock_ticker} 2021":total_assets_4 }
if total_assets_4 > total_assets_3:
    increase_assets = total_assets_4 - total_assets_3
    message_1 = (f"\nAssets has been increases ${increase_assets}")
    print(message_1)
elif total_assets_4 < total_assets_3:
    decrease_assets= total_assets_4 - total_assets_3
    message_2 = (f"\nAssets has been decreased ${decrease_assets}")
    print(message_2)
plotdata = pd.DataFrame({f"{stock_ticker}":[(total_assets_1), (total_assets_2), (total_assets_3), (total_assets_4)]}, index=["2018","2019","2020", "2021"])
plotdata.plot(kind="bar")
plotdata[f"{stock_ticker}"].plot(kind="line", color=["red"], figsize=(10,8))
plt.title(f"{stock_ticker}")
plt.xlabel("Total Assets")
plt.ylabel("Dollars ($)")
plt.show()
# Out:
# Assets has been increases $6671000000.0

# %% [markdown]
# #### Total Assets Validation

# %%
print(f"Assets 2018: ${total_assets_1}")
print(f"Assets 2019: ${total_assets_2}")
print(f"Assets 2020: ${total_assets_3}")
print(f"Assets 2021: ${total_assets_4}")
# Out:
# Assets 2018: $97334000000.0
# Assets 2019: $133376000000.0
# Assets 2020: $159316000000.0
# Assets 2021: $165987000000.0

# %%
print(f"Difference in Total assets: ${total_assets_4 - total_assets_3}")
# Out:
# Difference in Total assets: $6671000000.0

# %% [markdown]
# #### <font color="blue">Graph 4 - Total Liabilities<font>

# %%
stock = yfinance.Ticker(stock_ticker)
balance_sheet= stock.balance_sheet
total_lib_1 = float(balance_sheet.iloc[2:3,3])
total_lib_2 = float(balance_sheet.iloc[2:3,2])
total_lib_3 = float(balance_sheet.iloc[2:3,1])
total_lib_4 = float(balance_sheet.iloc[2:3,0])
rnd = {f"{stock_ticker} 2018":total_lib_1,f"{stock_ticker} 2019":total_lib_2,f"{stock_ticker} 2020":total_lib_3,f"{stock_ticker} 2021":total_lib_4 }
if total_lib_4 > total_lib_3:
    increase_lib = total_lib_4 - total_lib_3
    message_1 = (f"\nLiabilities has been increases ${increase_lib}")
    print(message_1)
elif total_lib_4 < total_lib_3:
    decrease_lib= total_lib_4 - total_lib_3
    message_2 = (f"\nLiabilities has been decreased ${decrease_lib}")
    print(message_2)
plotdata = pd.DataFrame({f"{stock_ticker}":[(total_lib_1), (total_lib_2), (total_lib_3), (total_lib_4)]}, index=["2018","2019","2020", "2021"])
plotdata.plot(kind="bar")
plotdata[f"{stock_ticker}"].plot(kind="line", color=["red"], figsize=(10,8))
plt.title(f"{stock_ticker}")
plt.xlabel("Total Liabilities")
plt.ylabel("Dollars ($)")
plt.show()
# Out:
# Liabilities has been increases $10082000000.0

# %% [markdown]
# #### Total Liabilities Validation

# %%
print(f"Liabilities 2018: ${total_lib_1}")
print(f"Liabilities 2019: ${total_lib_2}")
print(f"Liabilities 2020: ${total_lib_3}")
print(f"Liabilities 2021: ${total_lib_4}")
# Out:
# Liabilities 2018: $13207000000.0
# Liabilities 2019: $32322000000.0
# Liabilities 2020: $31026000000.0
# Liabilities 2021: $41108000000.0

# %%
print(f"Difference in Total Liabilities: ${total_lib_4 - total_lib_3}")
# Out:
# Difference in Total Liabilities: $10082000000.0

# %% [markdown]
# #### Balance Sheet Quarterly

# %%
df_quarterly_balance_sheet
# Out:
#                                                 2022-09-30    2022-06-30  \
# Intangible Assets                             8.750000e+08  9.650000e+08
# Capital Surplus                               6.209200e+10  5.992900e+10
# Total Liab                                    5.480000e+10  4.401200e+10
# Total Stockholder Equity                      1.240940e+11  1.257670e+11
# Other Current Liab                            1.489000e+09  1.514000e+09
# Total Assets                                  1.788940e+11  1.697790e+11
# Other Current Assets                          2.320000e+08  2.280000e+08
# Retained Earnings                             6.705600e+10  6.924900e+10
# Other Liab                                    6.987000e+09  6.469000e+09
# Good Will                                     2.026800e+10  2.022900e+10
# Gains Losses Not Affecting Retained Earnings -5.054000e+09 -3.411000e+09
# Other Assets                                  5.529000e+09  4.344000e+09
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.3 Cashflow Annual

# %%
df_cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.213200e+10 -1.452000e+10
# Change To Liabilities                      1.623000e+09  9.100000e+07
# Total Cashflows From Investing Activities -7.570000e+09 -3.005900e+10
# Net Borrowings                            -6.630000e+08 -5.800000e+08
# Total Cash From Financing Activities      -5.072800e+10 -1.029200e+10
# Change To Operating Activities             2.187000e+09 -1.302000e+09
# Net Income                                 3.937000e+10  2.914600e+10
# Change In Cash                            -1.089000e+09 -1.325000e+09
# Repurchase Of Stock                       -5.005200e+10 -9.836000e+09
# Effect Of Exchange Rate                   -4.740000e+08  2.790000e+08
# Total Cash From Operating Activities       5.768300e+10  3.874700e+10
# Depreciation                               7.967000e+09  6.862000e+09
# ...

# %% [markdown]
# #### Cashflow Quarterly

# %%
df_quarterly_cashflow
# Out:
#                                              2022-09-30    2022-06-30  \
# Investments                               -3.280000e+08  9.390000e+08
# Change To Liabilities                     -2.800000e+07  2.610000e+08
# Total Cashflows From Investing Activities -9.701000e+09 -6.959000e+09
# Net Borrowings                             9.567000e+09 -2.980000e+08
# Total Cash From Financing Activities       2.147000e+09 -6.563000e+09
# Change To Operating Activities             7.010000e+08  7.040000e+08
# Net Income                                 4.395000e+09  6.687000e+09
# Change In Cash                             1.773000e+09 -1.875000e+09
# Repurchase Of Stock                       -7.365000e+09 -6.235000e+09
# Effect Of Exchange Rate                   -3.650000e+08 -5.490000e+08
# Total Cash From Operating Activities       9.692000e+09  1.219600e+10
# Depreciation                               2.175000e+09  1.979000e+09
# ...

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.4 Stock Recommendations

# %%
data = stock.recommendations
df = pd.DataFrame(data)
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df)
# Out:
#                                    Firm           To Grade      From Grade  \
# Date
# 2022-01-19 14:03:49      Morgan Stanley         Overweight
# 2022-01-26 11:51:52         RBC Capital         Outperform
# 2022-02-03 09:37:12             Keybanc         Overweight
# 2022-02-03 10:23:02       Raymond James         Outperform      Strong Buy
# 2022-02-03 10:24:52         BMO Capital     Market Perform      Outperform
# 2022-02-03 11:37:44              Mizuho                Buy
# 2022-02-03 11:43:59      JMP Securities  Market Outperform
# 2022-02-03 11:47:37            Barclays         Overweight
# 2022-02-03 11:48:38       Goldman Sachs                Buy
# 2022-02-03 11:50:09       Piper Sandler            Neutral
# 2022-02-03 11:51:15   Truist Securities                Buy
# 2022-02-03 11:54:29                 UBS                Buy
# 2022-02-03 12:23:12           JP Morgan            Neutral      Overweight
# 2022-02-03 12:57:53      Morgan Stanley         Overweight
# ...

# %% [markdown]
# #### 2.5 Institutional Holders

# %%
df_institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  180403765    2022-06-29  0.0802
# 1                     Blackrock Inc.  151566495    2022-06-29  0.0674
# 2                           FMR, LLC  115273519    2022-09-29  0.0513
# 3           State Street Corporation   89882589    2022-06-29  0.0400
# 4      Price (T.Rowe) Associates Inc   51634675    2022-06-29  0.0230
# 5    Capital International Investors   49532448    2022-06-29  0.0220
# 6      Geode Capital Management, LLC   42657115    2022-06-29  0.0190
# 7            Capital World Investors   38385031    2022-06-29  0.0171
# 8                     Morgan Stanley   31958517    2022-06-29  0.0142
# 9  Capital Research Global Investors   31073962    2022-06-29  0.0138
#
#          Value
# 0  20389232914
# 1  17130044756
# 2  13028212730
# 3  10158529907
# 4   5835750795
# 5   5598157106
# 6   4821106994
# 7   4338276074
# 8   3611951484
# 9   3511979080

# %%
holders = df_institutional_holders["Holder"]
shares = df_institutional_holders["Shares"]

dic_institutional = {"holders":holders, "Shares":shares}
df_holders = pd.DataFrame(dic_institutional)
df_holders
# Out:
#                              holders     Shares
# 0         Vanguard Group, Inc. (The)  180403765
# 1                     Blackrock Inc.  151566495
# 2                           FMR, LLC  115273519
# 3           State Street Corporation   89882589
# 4      Price (T.Rowe) Associates Inc   51634675
# 5    Capital International Investors   49532448
# 6      Geode Capital Management, LLC   42657115
# 7            Capital World Investors   38385031
# 8                     Morgan Stanley   31958517
# 9  Capital Research Global Investors   31073962

# %% [markdown]
# #### <font color="blue">Institutional Holders - pie chart<font>

# %%
share = shares
companies = holders
comp = pd.DataFrame({"share" : share, "companies" : companies})
ax = comp.plot(y="share", kind="pie", labels = comp["companies"],figsize=(15,15), autopct = '%1.0f%%', legend=False, title='Institutional Holders')
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# #### 2.6 Major Holders

# %%
df_major_holders
percentage = df_major_holders[0]
major_holder = df_major_holders[1]

dic_major_holder = {"Percentage":percentage,"Major_holder":major_holder}
df_major_holder = pd.DataFrame(dic_major_holder)
df_major_holder
# Out:
#   Percentage                           Major_holder
# 0      0.55%        % of Shares Held by All Insider
# 1     75.80%       % of Shares Held by Institutions
# 2     76.22%        % of Float Held by Institutions
# 3       3935  Number of Institutions Holding Shares

# %% [markdown]
# #### 2.7 Earnings Annual

# %%
df_earnings
# Out:
#            Revenue     Earnings
# Year
# 2018   55838000000  22112000000
# 2019   70697000000  18485000000
# 2020   85965000000  29146000000
# 2021  117929000000  39370000000

# %% [markdown]
# #### <font color="blue">Graph 5 - Annual Earning<font>

# %%
stock = yfinance.Ticker(stock_ticker)
earnings = stock.earnings 
plotdata = pd.DataFrame(data=earnings)
sns.set_style('whitegrid')
plotdata.plot(kind="bar",figsize=(15,10))
plt.title(f"{stock_ticker}")
plt.xlabel("Quarter")
plt.ylabel("Dollars ($)")
plt.show()

# %% [markdown]
# #### 2.8 Earnings Quarterly

# %%
df_quarterly_earnings
# Out:
#              Revenue     Earnings
# Quarter
# 4Q2021   33671000000  10285000000
# 1Q2022   27908000000   7465000000
# 2Q2022   28822000000   6687000000
# 3Q2022   27714000000   4395000000

# %% [markdown]
# #### <font color="blue">Graph 6 - Quarterly Earning<font>

# %%
stock = yfinance.Ticker(stock_ticker)
earnings = stock.quarterly_earnings
plotdata = pd.DataFrame(data=earnings)
sns.set_style('whitegrid')
plotdata.plot(kind="bar",figsize=(15,10))
plt.title(f"{stock_ticker}")
plt.xlabel("Quarter")
plt.ylabel("Dollars ($)")
plt.show()

# %% [markdown]
# #### 2.9 Actions

# %%
df_actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %% [markdown]
# #### 2.10 Splits

# %%
df_splits
# Out:
# Empty DataFrame
# Columns: [Stock Splits]
# Index: []

# %% [markdown]
# #### 2.11 Dividends

# %%
df_dividends
# Out:
# Empty DataFrame
# Columns: [Dividends]
# Index: []

# %% [markdown]
# #### 2.12 Options

# %%
df_options
# Out:
#              0
# 0   2022-11-18
# 1   2022-11-25
# 2   2022-12-02
# 3   2022-12-09
# 4   2022-12-16
# 5   2022-12-23
# 6   2023-01-20
# 7   2023-02-17
# 8   2023-03-17
# 9   2023-06-16
# 10  2023-09-15
# 11  2024-01-19
# 12  2024-06-21
# 13  2025-01-17

# %% [markdown]
# #### 2.13 Sustainability

# %%
df_sustainability
# Out:
#                                      Value
# 2022-8
# palmOil                              False
# controversialWeapons                 False
# gambling                             False
# socialScore                          21.01
# nuclear                              False
# furLeather                           False
# alcoholic                            False
# gmo                                  False
# catholic                             False
# socialPercentile                      None
# peerCount                              105
# governanceScore                      10.51
# environmentPercentile                 None
# animalTesting                        False
# tobacco                              False
# totalEsg                             32.54
# highestControversy                       4
# esgPerformance                    OUT_PERF
# coal                                 False
# pesticides                           False
# adult                                False
# ...

# %% [markdown]
# #### 2.14 Calendar

# %%
df_calendars
# Out:
#                                     0                    1
# Earnings Date     2023-01-31 10:59:00  2023-02-06 12:00:00
# Earnings Average                 2.26                 2.26
# Earnings Low                     1.41                 1.41
# Earnings High                    3.34                 3.34
# Revenue Average           31518300000          31518300000
# Revenue Low               30007600000          30007600000
# Revenue High              32434000000          32434000000

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.15 Comapny Information

# %%
stock.info
# Out:
# {'zip': '94025',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 87314,
# ...

# %% [markdown]
# ##### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.16 News

# %%
df_news
# Out:
#                                    uuid  \
# 0  7e3bb9fd-4f5e-33bf-a527-08dec648eedd
# 1  22cb61c9-5a22-39af-934b-a880fcfa2ad1
# 2  3f6eb657-44f0-3191-bd17-b2f77b7e2f1b
# 3  dd7fed01-ae0a-39cb-a0cc-15493ba8c3b5
# 4  a8f4f277-34f4-3cfa-b1c7-8c38df868e97
# 5  b8daf351-a2b8-329b-b3bb-1a518d2d3b90
# 6  2c0451ee-eeb0-3730-ba9a-fbd2c3ccdecf
# 7  9ec380df-7054-3b5c-855c-dcd21a906001
#
#                                                title  \
# 0          Meta Platforms Stock Q&A With Wall Street
# 1  There Is A Reason Meta Platforms, Inc.'s (NASD...
# 2         Is The Trade Desk a Good Stock to Buy Now?
# 3  Buzly's student-only social media platform exp...
# 4  Meta’s massive layoffs and other job cuts spar...
# 5  Meta Platforms Is Near a 52-Week Low. Is It a ...
# 6  RPT-UPDATE 2-Nearly half Meta job cuts were in...
# 7  Nearly half of Meta job cuts were in tech, reo...
#
#                          publisher  \
# 0                      Motley Fool
# 1                  Simply Wall St.
# ...

# %% [markdown]
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Conclusion

# %% [markdown]
# ##### 3.1 Institutional Holders, still have strong holding in Meta.

# %% [markdown]
# 1. Vanguard Group has holding 23%
#
# 2. Blackrock has holding of 19%
#
# 3. Fidelity Investments Limited liability company has holding of 15%
#
# 4. State Street Corporation has holding of 11%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 3.2 Quarterly Earning.
#
# It shows company is going into loss because revenue is the income of a company generates before deducting expenses. earnings, on the other hand, represents the profit a company has earned.

# %% [markdown]
# ![image.png](attachment:image.png)
